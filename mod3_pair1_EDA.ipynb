# %% [markdown]
# Abrid el fichero de rating-and-performance con el método que sea más correcto.

# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/lucianayelicich/Desktop/Adalab/Pair Programming/pair_mod3_LucianaMartaAna/spaces_o50fZDRQYNgRINpMJz49_uploads_git-blob-c1c10e8f39ba5f814f77ecb77c93154834b00430_rating-and-performance.csv", index_col=0)
df.head()
# Out:
#                                                    title  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...
# 1      SSHOUSE Summer Casual Sleeveless Soirée Party ...
# 2      2020 Nouvelle Arrivée Femmes Printemps et Été ...
# 3      Hot Summer Cool T-shirt pour les femmes Mode T...
# 4      Femmes Shorts d'été à lacets taille élastique ...
#
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %% [markdown]
# Mostrad las 10 últimas filas.

# %%
df.tail(10)
# Out:
#                                                    title  \
# index
# 1563   ZANZEA Femmes Été Polka Dot Kaftan Beach Club ...
# 1564   2018 Femme mode d'été en dentelle Patchwork Pa...
# 1565   Nouveau Pantalon De Mode D'été Femmes Leggings...
# 1566   Robe mi-longue d'été à manches courtes pour fe...
# 1567   Combinaison sans manches pour femmes couleur u...
# 1568   Nouvelle Mode Femmes Bohême Pissenlit Imprimer...
# 1569   10 couleurs femmes shorts d'été lacent ceintur...
# 1570   Nouveautés Hommes Siwmwear Beach-Shorts Hommes...
# 1571   Mode femmes d'été sans manches robes col en V ...
# 1572   Pantalon de yoga pour femmes à la mode Slim Fi...
#
#                                               title_orig  price  retail_price  \
# index
# 1563   ZANZEA Women Summer Polka Dot Kaftan Beach Clu...  15.00            92
# 1564   2018 Women fashion Summer Lace Patchwork Tank ...   5.91             5
# 1565   New Summer Fashion Trousers Women Leggings Rip...   3.00             8
# ...

# %% [markdown]
# Mostrad 5 filas aleatorias del DataFrame.

# %%
df.sample(5)
# Out:
#                                                    title  \
# index
# 751    Mode féminine Maillots de bain Deux pièces Spl...
# 1203   2019 Summer Women Plus Size Genou-longueur Sli...
# 63     Robe en coton à manches courtes pour femmes d'...
# 81     7 Couleurs Top 2018 Femme Femme Femme Sexy Top...
# 561    Femmes classiques dos nu en dentelle évider li...
#
#                                               title_orig  price  retail_price  \
# index
# 751    Women Fashion Swimwear Two Pieces Split Bikini...   7.00             6
# 1203   2019 Summer Women's Plus Size Knee-length Slin...   5.00             7
# 63     European and American Classic Fashion Summer L...   5.87            11
# 81     7 Colors Tops 2018 Women Lady Sexy Summer Slee...   5.77             5
# 561    Classic Women Backless Lace Hollow Out Halter ...   8.00             7
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# ...

# %% [markdown]
# ¿Cuántas filas y columnas tenemos en el DataFrame?

# %%
df.shape
# Out:
# (1573, 43)

# %% [markdown]
# ¿Cuáles son los nombres de las columnas del DataFrame?

# %%
df.columns
# Out:
# Index(['title', 'title_orig', 'price', 'retail_price', 'currency_buyer',
#        'units_sold', 'uses_ad_boosts', 'rating', 'rating_count',
#        'rating_five_count', 'rating_four_count', 'rating_three_count',
#        'rating_two_count', 'rating_one_count', 'badges_count',
#        'badge_local_product', 'badge_product_quality', 'badge_fast_shipping',
#        'tags', 'product_color', 'product_variation_size_id',
#        'product_variation_inventory', 'shipping_option_name',
#        'shipping_option_price', 'shipping_is_express', 'countries_shipped_to',
#        'inventory_total', 'has_urgency_banner', 'urgency_text',
#        'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
# Seleccionad solo las columnas de tipo categórico del DataFrame. Después, mostrad los valores únicos y sus frecuencias para cada una de las columnas seleccionadas.

# %%
df.describe(include="object").T
# Out:
#                           count unique  \
# title                      1573   1201
# title_orig                 1573   1203
# currency_buyer             1573      1
# tags                       1573   1230
# product_color              1532    101
# product_variation_size_id  1559    106
# shipping_option_name       1573     15
# urgency_text                473      2
# origin_country             1556      6
# merchant_title             1573    958
# merchant_name              1569    957
# merchant_info_subtitle     1572   1058
# merchant_id                1573    958
# merchant_profile_picture    226    125
# product_url                1573   1341
# product_picture            1573   1341
# product_id                 1573   1341
# theme                      1573      1
# crawl_month                1573      1
#
#                                                                          top  \
# title                      Nouvelle mode d'été femmes robe décontractée c...
# ...

# %% [markdown]
# En el DataFrame tenemos dos columnas que parece que nos dan la misma información "title" y "title_orig". Eliminad "title".

# %%
df.drop("title", axis=1, inplace=True)
df.head()
# Out:
#                                               title_orig  price  retail_price  \
# index
# 0      2020 Summer Vintage Flamingo Print  Pajamas Se...  16.00            14
# 1       Women's Casual Summer Sleeveless Sexy Mini Dress   8.00            22
# 2      2020 New Arrival Women Spring and Summer Beach...   8.00            43
# 3      Hot Summer Cool T Shirt for Women Fashion Tops...   8.00             8
# 4      Women Summer Shorts Lace Up Elastic Waistband ...   2.72             3
#
#       currency_buyer  units_sold  uses_ad_boosts  rating  rating_count  \
# index
# 0                EUR         100               0    3.76            54
# 1                EUR       20000               1    3.45          6135
# 2                EUR         100               0    3.57            14
# 3                EUR        5000               1    4.03           579
# 4                EUR         100               1    3.10            20
#
# ...

# %%
df.columns
# Out:
# Index(['title_orig', 'price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %% [markdown]
# ¿En que columnas tenemos valores nulos? Utilizad el método que más os guste.

# %%
df.isnull().sum()
# Out:
# title_orig                         0
# price                              0
# retail_price                       0
# currency_buyer                     0
# units_sold                         0
# uses_ad_boosts                     0
# rating                             0
# rating_count                       0
# rating_five_count                 45
# rating_four_count                 45
# rating_three_count                45
# rating_two_count                  45
# rating_one_count                  45
# badges_count                       0
# badge_local_product                0
# badge_product_quality              0
# badge_fast_shipping                0
# tags                               0
# product_color                     41
# product_variation_size_id         14
# product_variation_inventory        0
# shipping_option_name               0
# shipping_option_price              0
# shipping_is_express                0
# countries_shipped_to               0
# ...

# %% [markdown]
# ¿Tenemos valores duplicados en el DataFrame?

# %%
columnas = df.columns
columnas
# Out:
# Index(['title_orig', 'price', 'retail_price', 'currency_buyer', 'units_sold',
#        'uses_ad_boosts', 'rating', 'rating_count', 'rating_five_count',
#        'rating_four_count', 'rating_three_count', 'rating_two_count',
#        'rating_one_count', 'badges_count', 'badge_local_product',
#        'badge_product_quality', 'badge_fast_shipping', 'tags', 'product_color',
#        'product_variation_size_id', 'product_variation_inventory',
#        'shipping_option_name', 'shipping_option_price', 'shipping_is_express',
#        'countries_shipped_to', 'inventory_total', 'has_urgency_banner',
#        'urgency_text', 'origin_country', 'merchant_title', 'merchant_name',
#        'merchant_info_subtitle', 'merchant_rating_count', 'merchant_rating',
#        'merchant_id', 'merchant_has_profile_picture',
#        'merchant_profile_picture', 'product_url', 'product_picture',
#        'product_id', 'theme', 'crawl_month'],
#       dtype='object')

# %%
df.duplicated()
# Out:
# index
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# Length: 1573, dtype: bool

# %%
df.duplicated(subset="title_orig").sum()
# Out:
# 370

# %%
for col in df.columns:
    print(f"Duplicados en la columna '{col}': {df.duplicated(subset=col).sum()}")
# Out:
# Duplicados en la columna 'title_orig': 370
# Duplicados en la columna 'price': 1446
# Duplicados en la columna 'retail_price': 1469
# Duplicados en la columna 'currency_buyer': 1572
# Duplicados en la columna 'units_sold': 1558
# Duplicados en la columna 'uses_ad_boosts': 1571
# Duplicados en la columna 'rating': 1381
# Duplicados en la columna 'rating_count': 812
# Duplicados en la columna 'rating_five_count': 967
# Duplicados en la columna 'rating_four_count': 1132
# Duplicados en la columna 'rating_three_count': 1188
# Duplicados en la columna 'rating_two_count': 1310
# Duplicados en la columna 'rating_one_count': 1242
# Duplicados en la columna 'badges_count': 1569
# Duplicados en la columna 'badge_local_product': 1571
# Duplicados en la columna 'badge_product_quality': 1571
# Duplicados en la columna 'badge_fast_shipping': 1571
# Duplicados en la columna 'tags': 343
# Duplicados en la columna 'product_color': 1471
# Duplicados en la columna 'product_variation_size_id': 1466
# ...

# %%
df.duplicated()
# Out:
# index
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1568    False
# 1569    False
# 1570    False
# 1571    False
# 1572    False
# Length: 1573, dtype: bool

# %%
df[df.duplicated()]
# Out:
#                                               title_orig  price  retail_price  \
# index
# 311    Women's Summer Fashion Spaghetti Strap Dress F...   8.00             7
# 411    New Women Ladies Fashion Summer Skinny High Wa...  14.00            12
# 447    Womens Summer Fashion Lip Print 2pc Set Ladies...   5.00            51
# 505    Plus Size Women's Fashion Loose Casual sleevel...   5.83             5
# 571    Summer Women Fashion Short Dress Sleeveless Wa...   8.00            51
# 684    Summer Women Boho Maxi Polka Dot Dress Irregul...   6.00             6
# 689    Summer Women Fashion Double-Layer Sports Short...   3.76             7
# 698    Women's Summer Sleeveless Tank Cotton Vest Pri...   6.00             7
# 770    New Fashion Summer Women Casual Dress Round Ne...   2.00             9
# 991    2020 Summer Men's Classic Shorts Multi-pocket ...   7.00            17
# 997    S-5XL New Fashion Women Tops Blouse Sleeveless...   4.83            51
# ...
