# %%
import pandas as pd

# %%
# Configuración para mostrar todas las columnas del DataFrame
pd.set_option('display.max_columns', None)

# %%
df=pd.read_csv('merchant_fill.csv', index_col=0)
df.head(3)
# Out:
#                                                title  price  retail_price  \
# 0  2020 Summer Vintage Flamingo Print  Pajamas Se...   16.0            14
# 1  SSHOUSE Summer Casual Sleeveless Soirée Party ...    8.0            22
# 2  Nouvelle mode d'été femmes robe décontractée c...    4.9             8
#
#    units_sold  uses_ad_boosts  rating_sold  rating_count  rating_five_count  \
# 0         100               0         3.76            54               26.0
# 1       20000               1         3.45          6135             2269.0
# 2        1000               1         3.83            99               43.0
#
#    rating_four_count  rating_three_count  rating_two_count  rating_one_count  \
# 0                8.0                10.0               1.0               9.0
# 1             1027.0              1118.0             644.0            1077.0
# 2               18.0                23.0               8.0               7.0
#
# ...

# %%
df.sample().T
# Out:
#                                                                           1472
# title                        Women Fashion Jumpsuit Short Romper V Neck Sum...
# price                                                                      8.0
# retail_price                                                                 7
# units_sold                                                                 100
# uses_ad_boosts                                                               1
# rating_sold                                                               3.37
# rating_count                                                                19
# rating_five_count                                                          9.0
# rating_four_count                                                          2.0
# rating_three_count                                                         1.0
# rating_two_count                                                           1.0
# ...

# %% [markdown]
# 1. Total de unidades vendidas por país de origen del vendedor.
# - Debéis agrupar los datos según el país de origen del vendedor y calcular el total de unidades vendidas para cada país.
# Esto nos dará una idea de qué países tienen una mayor participación en las ventas totales y cuáles tienen menos.
# - Devuelve los resultados en un DataFrame ordenados de mayor a menor en función de la cantidad de unidades vendidas.

# %%
# Miramos los valores únicos de la columna:
df['origin_country'].unique()
# Out:
# array(['CN', 'US', nan, 'VE', 'AT', 'SG', 'GB'], dtype=object)

# %%
# Identificamos las columnas:
# origin_country, total_units_sold	
venta_pais = df.groupby('origin_country')['total_units_sold'].sum().reset_index()
venta_pais
# Out:
#   origin_country  total_units_sold
# 0             AT               100
# 1             CN          17371643
# 2             GB              1000
# 3             SG             40200
# 4             US             60460
# 5             VE               650

# %%
venta_pais_ordenado = venta_pais.sort_values(by='total_units_sold', ascending= False)
venta_pais_ordenado
# Out:
#   origin_country  total_units_sold
# 1             CN          17371643
# 4             US             60460
# 3             SG             40200
# 2             GB              1000
# 5             VE               650
# 0             AT               100

# %% [markdown]
# 2. Estadísticas de precio por país de envío.
# - Vamos a explorar el precio promedio y el precio máximo de los productos según el país al que se envían.
# Al hacer esto, podremos entender cómo varían los precios según el destino del envío y si hay alguna tendencia interesante que valga la pena analizar.
# - Devuelve los resultados en un DataFrame.

# %%
# Columnas: origin_country, price
precio_pais_envio = df.groupby('origin_country')['price'].agg(['mean', 'max'])
precio_pais_envio
# Out:
#                     mean    max
# origin_country
# AT              7.000000   7.00
# CN              8.341629  49.00
# GB              9.000000   9.00
# SG              3.380000   3.93
# US              9.397097  16.00
# VE              8.298000  16.00

# %% [markdown]
# 3. Conteo de productos con y sin distintivo de producto local.
# - Vamos a clasificar los productos según si tienen o no un distintivo de producto local.
# - Luego, calcularemos el conteo de productos en cada categoría para comprender cuántos productos tienen este distintivo y cuántos no.
# Esto puede proporcionarnos información sobre cómo se promocionan los productos con esta característica. Devuelve los resultados en un DataFrame.

# %%
# columna categoría: tags	
df['tags'].unique()
# Out:
# array(["Summer,Fashion,womenunderwearsuit,printedpajamasset,womencasualshort,Women's Fashion,flamingo,loungewearset,Casual,Shirt,casualsleepwear,Shorts,flamingotshirt,Elastic,Vintage,Tops,tshirtandshortsset,Women,Sleepwear,Print,womenpajamasset,womennightwear,Pajamas,womensleepwearset",
#        "Mini,womens dresses,Summer,Patchwork,fashion dress,Dress,Mini dress,Women's Fashion,Women S Clothing,backless,party,summer dresses,sleeveless,sexy,Casual",
#        "Summer,Fashion,Necks,Beach,Dress,Loose,beach dress,Round neck,Women's Fashion,sleeveless,Skirts,Casual,Women",
#        ...,
#        "Summer,Plus Size,tunic,Tops,blousetop,Casual,Women's Fashion,Printing,tank top,sleeveless,V-neck,Tank,Fashion,plusszie",
#        "runningshort,Beach Shorts,beachpant,menbeachshort,Men,sailboatshort,beach swimwear,Men's Fashion,Shorts,Summer,men's shorts,Sport",
#        "Summer,Leggings,slim,Yoga,pants,Slim Fit,Women's Fashion,Running,Fashion,Sport,Fitness,Women"],
#       dtype=object)

# %%
# Columnas: badge_local_product, product_id	
df['badge_local_product'].unique()
# 0=no, 1=si
# Out:
# array([0, 1], dtype=int64)

# %%
# mapeo: diccionario
dic_map={0:'no', 1:'si'}
df['badge_local_product'] = df['badge_local_product'].map(dic_map)
df['badge_local_product'].unique() # display no hace falta si es la ÚLTIMA línea del código
# Out:
# array(['no', 'si'], dtype=object)

# %%
producto_local = df.groupby('badge_local_product')['product_id'].count().reset_index()
producto_local
# Out:
#   badge_local_product  product_id
# 0                  no        1544
# 1                  si          29
